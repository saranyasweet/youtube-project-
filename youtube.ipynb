# %%
#API KEY CONNECTION
from googleapiclient.discovery import build
import pymongo

# %%
def Api_connect():
    Api_ID="AIzaSyDhIXoCZZnJzMH2lv5Kr4Se93bDj-iZhGo"


    api_service_name="youtube"
    api_version="v3"


    youtube=build(api_service_name,api_version,developerKey=Api_ID)


    return youtube

#to access the function 
youtube=Api_connect()

# %%
#  requesting youtube to get channels informatio
def get_channel_info(channel_id):
    request = youtube.channels().list(

                            part="snippet,contentDetails,statistics",
                            id=channel_id)


    response = request.execute()
    for i in response["items"]:
            data=dict(Channel_Name=i["snippet"]["title"],
                    Channel_Id=i["id"],
                    Subscribers=i["statistics"]["subscriberCount"],
                    Views=i["statistics"]["viewCount"],
                    Total_Videos=i["statistics"]["videoCount"],
                    Channel_Description=i["snippet"]["description"],
                    Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
            
    return data

# %%
get_channel_info
# Out:
# <function __main__.get_channel_info(channel_id)>

# %%
Channel_details=get_channel_info("UC5cY198GU1MQMIPJgMkCJ_Q")

# %%
Channel_details
# Out:
# {'Channel_Name': 'Mr. GK',
#  'Channel_Id': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#  'Subscribers': '1380000',
#  'Views': '197815810',
#  'Total_Videos': '500',
#  'Channel_Description': 'Please contact me thru my mail id given below.\n\nFollow us on my social media:\nWhatsApp: https://whatsapp.com/channel/0029VaA23u5IHphLuhO3LM01\nYoutube: https://www.youtube.com/MrGKTamil\nFacebook: https://www.facebook.com/MrGKTamil\nTwitter: https://twitter.com/Mr_GK_Tamil\nInstagram: http://instagram.com/Mr_Gk_Tamil\nTelegram: https://t.me/MrGkGroup\n',
#  'Playlist_Id': 'UU5cY198GU1MQMIPJgMkCJ_Q'}

# %%
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part="contentDetails").execute()
    Playlist_Id=response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

    next_page_token=None

    while True:


        response1=youtube.playlistItems().list(
                                            part="snippet",
                                            playlistId=Playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1["items"])):

            video_ids.append(response1["items"][i]["snippet"]["resourceId"]["videoId"])

        next_page_token=response1.get("nextPageToken")


        if next_page_token is None:
            break


    return video_ids

# %%
Video_Ids=get_videos_ids("UC5cY198GU1MQMIPJgMkCJ_Q")

# %%
Video_Ids
# Out:
# ['Yz-uD-kP7og',
#  'ewGh3gzt0zI',
#  'NWFA-km1rJY',
#  'soj3Z0WPoA0',
#  'YVN_MfiP0Bc',
#  'KQYSiSo7q-4',
#  'gzf_5ReWwNs',
#  'v6MhhxmAPKU',
#  'V1444BVE71o',
#  'yTlFCdG2eAc',
#  'i5T2ARz05oA',
#  'JtS4sZYiBCI',
#  '0WWIEXcijwY',
#  'EVxiuXV_OxM',
#  'UVLXcaRx0lU',
#  'cfKWEHk1oWc',
#  '9Haiiar8x0g',
#  'oUL3Pb3ImbQ',
#  'hnsmfdNSPv0',
#  '4cuQuKoKKNo',
#  'a1kVpra4_Z4',
#  'rf6JCKZCaXo',
#  'QuZ-tyY877Y',
#  'e4t2WAhGr08',
#  'jRDDvpkKQAk',
#  'hua0FANT_-E',
#  'OAJbMwp0ruU',
#  'K1WVzZmDEoo',
#  'UnqoTiWXUBo',
#  'PuL_CP_Vr5s',
#  'DHMv_7WNSl4',
#  'Dp1hC-p_do0',
#  '2jXqIfic1U8',
#  'lhiI5slH81U',
#  'OrqdeC6_OnA',
#  '9ROJBtbni_g',
#  'r9xv8ZsCpT4',
#  'c3peKw--wmE',
#  'ooV9WAxtTU0',
#  'QKmnSh0XE1o',
#  'Lsbexi-6KRw',
#  'hP38eGcmX6c',
#  'IND1IkA-M-o',
#  'LMuAa43tD2w',
#  'LGEVX7UBZfI',
#  '1fHl6m54w9Q',
#  'UI3HKcPda9g',
#  'sS5mbtg87JM',
#  'PmGQ1n-9Pqs',
#  'i6JREnRGAKA',
#  'OS8tc7UqoH8',
#  'lpaR7sKCAdA',
#  'gz-RIZXvFNE',
#  'Vm6MoiKL_FA',
#  '3Sxl3YUMOAs',
# ...

# %%
#get video informatiom
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
            request=youtube.videos().list(
                part="snippet,contentDetails,statistics",
                id=video_id
            )

            response=request.execute()

            for item in response["items"]:
                    data=dict(Channel_Name=item["snippet"]["channelTitle"],
                            Channel_Id=item["snippet"]["channelId"],
                            Video_Id=item["id"],
                            Title=item["snippet"]["title"],
                            Thumbnail=item["snippet"]["thumbnails"],
                            Description=item["snippet"]["description"],
                            Published=item["snippet"]["publishedAt"],
                            Duration=item["contentDetails"]["duration"],
                            Views=item["statistics"]["viewCount"],
                            favorite_count=item["statistics"]["favoriteCount"],
                            caption=item["contentDetails"]["caption"]
                            
                            )
                    video_data.append(data)

    return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Mr. GK',
#   'Channel_Id': 'UC5cY198GU1MQMIPJgMkCJ_Q',
#   'Video_Id': 'Yz-uD-kP7og',
#   'Title': '#ESP | Water Memory | MLM | என்னென்ன சொல்றாங்க பாருங்க | Mr.GK',
#   'Thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Yz-uD-kP7og/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Yz-uD-kP7og/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Yz-uD-kP7og/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Yz-uD-kP7og/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Yz-uD-kP7og/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
# ...

# %%
#get comment information
def get_comment_info(video_ids):
        Comment_data=[]
        try:
                        for video_id in video_ids:
                                request=youtube.commentThreads().list(
                                        part="snippet",
                                        videoId=video_id,
                                        maxResults=50
                                        )

                                response=request.execute()


                                for item in response["items"]:
                                 data=dict(Comment_Id=item["snippet"]["topLevelComment"]["id"],
                                        Video_Id=item["snippet"]["topLevelComment"]["snippet"]["videoId"],
                                        Comment_Text=item["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                                        Comment_Author=item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                                        Comment_Published=item["snippet"]["topLevelComment"]["snippet"]["publishedAt"])
                                Comment_data.append(data)
                                
        except:
                pass

        return Comment_data

# %%
Comment_details=get_comment_info(Video_Ids)

# %%
Comment_details
# Out:
# [{'Comment_Id': 'UgwVoP0HbLknlJMmEXp4AaABAg',
#   'Video_Id': 'Yz-uD-kP7og',
#   'Comment_Text': 'Telepathy is possible. I disagree with you sir.',
#   'Comment_Author': '@Wyness',
#   'Comment_Published': '2024-02-18T05:00:04Z'},
#  {'Comment_Id': 'UgywyQU2kQ5CwQHrLJ94AaABAg',
#   'Video_Id': 'ewGh3gzt0zI',
#   'Comment_Text': 'ஊசி ஏன் இந்தியர்களுக்கு/ இந்தியாவில் அதிகம் போடபடுகிறது.!?',
#   'Comment_Author': '@vivekond8702',
#   'Comment_Published': '2024-02-11T14:38:17Z'},
#  {'Comment_Id': 'UgzR6gDhvkFv7lCWFwN4AaABAg',
#   'Video_Id': 'NWFA-km1rJY',
#   'Comment_Text': 'Mercury pathi oru video podunga Dharmadurai sir.',
#   'Comment_Author': '@vignesh170794',
#   'Comment_Published': '2024-02-12T14:23:05Z'},
#  {'Comment_Id': 'Ugx6NIvvpRenmr4HTM94AaABAg',
#   'Video_Id': 'soj3Z0WPoA0',
#   'Comment_Text': 'Myv3super❤❤❤❤❤❤',
#   'Comment_Author': '@user-hv4hk5dz4u',
#   'Comment_Published': '2024-02-15T04:01:07Z'},
#  {'Comment_Id': 'UgyuUElqBLhTZhM59Qd4AaABAg',
# ...

# %%
len(Comment_details)
# Out:
# 153

# %%
#get_playlist_details
def get_playlist_details(channel_id):
        next_page_token=None
        All_data=[]
        while True:
                request=youtube.playlists().list(
                        part="snippet,contentDetails",
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()     

                for item in response['items']:
                        data=dict(Playlist_Id=item["id"],
                        Title=item["snippet"]["title"],
                        Channel_Id=item["snippet"]["channelId"],
                        Channel_Name=item["snippet"]["channelTitle"],
                        PublishedAt=item["snippet"]["publishedAt"],
                        Video_Count=item["contentDetails"]["itemCount"])
                All_data.append(data)

                next_page_token=response.get("next_page_token")
                if next_page_token is None:
                  break

        return All_data

# %%
playlist_details=get_playlist_details("UChGd9JY4yMegY6PxqpBjpRA")

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLgctjL4oxHAspkFL8qJdpeV5GJaH0-KIA',
#   'Title': 'Science Battle Between Scientists',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'PublishedAt': '2021-10-13T09:42:58Z',
#   'Video_Count': 5}]

# %%
#upload to mongodb
client=pymongo.MongoClient("mongodb+srv://saranyaswetha2004:saranya2004@cluster0.aigdoh5.mongodb.net/?retryWrites=true&w=majority")
db=client["Youtube_data"]
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[137], line 2
#       1 #upload to mongodb
# ----> 2 client=pymongo.MongoClient("mongodb+srv://saranyaswetha2004:saranya2004@cluster0.aigdoh5.mongodb.net/?retryWrites=true&w=majority")
#       3 db=client["Youtube_data"]
#
# File c:\Users\TC ADMIN\New folder\.venv\Lib\site-packages\pymongo\mongo_client.py:771, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     767 if timeout is not None:
#     768     timeout = common.validate_timeout_or_none_or_zero(
#     769         keyword_opts.cased_key("connecttimeoutms"), timeout
#     770     )
# --> 771 res = uri_parser.parse_uri(
#     772     entity,
#     773     port,
#     774     validate=True,
#     775     warn=True,
#     776     normalize=False,
#     777     connect_timeout=timeout,
# ...

# %%
def channel_details(channel_id):
    chn_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":chn_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "uploaded successfully"

# %%
insert=channel_details("UCcb5MEQMvqLROAEpfF9hlvg")

# %%
get_channel_info("UCcb5MEQMvqLROAEpfF9hlvg")
# Out:
# {'Channel_Name': 'All in One-India',
#  'Channel_Id': 'UCcb5MEQMvqLROAEpfF9hlvg',
#  'Subscribers': '73000',
#  'Views': '14056430',
#  'Total_Videos': '41',
#  'Channel_Description': 'Welcome to All in One India Youtube Channel',
#  'Playlist_Id': 'UUcb5MEQMvqLROAEpfF9hlvg'}

# %%
import psycopg2

# %%
#table creation

mydb=psycopg2.connect(host="localhost",
                    user="postgres",
                    password="saranya@2004",
                    database="youtube_data",
                    port="5432")
cursor=mydb.cursor()

drop_query='''drop table if exists channels'''
cursor.execute(drop_query)
mydb.commit()



try:
    create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                        Channel_Id varchar(80) primary key,
                                                        Subscribers bigint,
                                                        Views bigint,
                                                        Total_Videos int,
                                                        Channel_Description text,
                                                        Playlist_Id varchar(80))'''
    
    cursor.execute(create_query)
    mydb.commit()


except:
    print("channels table is already created")

# %%
ch_list=[]
db=client["Youtube_data"]
coll1=db["channel_details"]
for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
    #print(ch_data)
    ch_list.append(ch_data["channel_information"])
ch_list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 6
#       3 coll1=db["channel_details"]
#       4 for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
#       5     #print(ch_data)
# ----> 6     ch_list.append(ch_data["channel_information"])
#       7 ch_list
#
# KeyError: 'channel_information'

# %%
ch_list
# Out:
# [{'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#   'Channel_Id': 'UChGd9JY4yMegY6PxqpBjpRA',
#   'Subscribers': '59200',
#   'Views': '3889302',
#   'Total_Videos': '260',
#   'Channel_Description': 'நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பானில் 1.5 வருட ஆராய்ச்சி, அமெரிக்காவில் 2 வருட ஆராய்ச்சி, ஐரோப்பாவில் சுமார் 6 வருட ஆராய்ச்சி ! தற்போது நம்ம ஊரில்  !\n\nஎளிய தமிழில் அனைவரும் ஆர்வமுடன் அறிவியலை தெரிந்துகொள்ளவேண்டும் என்ற நோக்கத்தில் இந்த முயற்சி! என்னுடன் தொடர்பு கொள்ள விரும்பினால் sciencewithsam2020@gmail.com\n\nConnect with me by email sciencewithsam2020@gmail.com\n\nநான் யாரிடமும் பணமோ உதவியோ இந்த சேனல் மூலம் கேட்பதில்லை. ஒரு வேலை என்னுடைய சேனலுக்கு உதவ விரும்பும் நண்பர்கள், தனிப்பட்ட முறையில் மின்னஞ்சல் அனுப்பலாம் \n\nI never ask for money through my channel. If you really want to support my work by any means, write to me personally at my email ID sciencewithsam2020@gmail.com \n\n',
#   'Playlist_Id': 'UUhGd9JY4yMegY6PxqpBjpRA'},
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(ch_list)

# %%
df
# Out:
#                             Channel_Name                Channel_Id  \
# 0  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 1                            Madan Gowri  UCY6KjrDBN_tIRFT_QNqQbRQ
# 2  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 3  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
#
#   Subscribers       Views Total_Videos  \
# 0       59200     3889302          260
# 1     7250000  1879236820         2638
# 2       59200     3891515          260
# 3       59200     3891515          260
#
#                                  Channel_Description               Playlist_Id
# 0  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...  UUhGd9JY4yMegY6PxqpBjpRA
# 1                            Common Man! MG Squad 🖖🏻  UUY6KjrDBN_tIRFT_QNqQbRQ
# 2  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...  UUhGd9JY4yMegY6PxqpBjpRA
# 3  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...  UUhGd9JY4yMegY6PxqpBjpRA

# %%
for index,row in df.iterrows():
    insert_query='''insert into channels(Channel_Name,
                                         Channel_Id,
                                         Subscribers,
                                         Views,
                                         Total_Videos,
                                         Channel_Description,
                                         Playlist_Id)
                                         
                                         values(%s,%s,%s,%s,%s,%s,%s)'''
    
    values=(row["Channel_Name"],
            row["Channel_Id"],
            row["Subscribers"],
            row["Views"],
            row["Total_Videos"],
            row["Channel_Description"],
            row["Playlist_Id"])
    

    try:
        cursor.execute(insert_query,values)
        mydb.commit()
    except:
        print("channels values are already insert")
# Out:
# channels values are already insert
# channels values are already insert

# %%
(insert_query,values)
# Out:
# ('insert into channels(Channel_Name,\n                                         Channel_Id,\n                                         Subscribers,\n                                         Views,\n                                         Total_Videos,\n                                         Channel_Description,\n                                         Playlist_Id)\n                                         \n                                         values(%s,%s,%s,%s,%s,%s,%s)',
#  ('Science With Sam - அறிவியல் அறிவோம் !',
#   'UChGd9JY4yMegY6PxqpBjpRA',
#   '59200',
#   '3891515',
#   '260',
# ...
